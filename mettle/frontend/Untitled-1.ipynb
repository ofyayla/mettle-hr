# %%
import pyautogui
import time

while True:
    pyautogui.click()
    time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 while True:
#       5     pyautogui.click()
# ----> 6     time.sleep(10)
#
# KeyboardInterrupt:
